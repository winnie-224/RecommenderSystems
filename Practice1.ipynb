# %% [markdown]
# Data Preparation

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b5aaa67a0376> in <cell line: 4>()
#       2 from datetime import datetime, timedelta
#       3
# ----> 4 from recommenders.datasets.download_utils import maybe_download
#       5 from recommenders.datasets.python_splitters import (
#       6     python_random_split,
#
# ModuleNotFoundError: No module named 'recommenders'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install recommenders
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.0/356.0 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.4/316.4 kB 37.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 747.7/747.7 kB 22.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 75.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 20.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.9/251.9 kB 26.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 78.4 MB/s eta 0:00:00
# ...

# %%
# import pandas as pd
# from datetime import datetime, timedelta

# %%
# from recommenders.datasets.download_utils import maybe_download
# from recommenders.datasets.python_splitters import(
#     python_random_split,
#     python_chrono_split,
#     python_stratified_split
# )

# %%
# DATA_URL = "https://files.grouplens.org/datasets/movielens/ml-100k/u.data"
# DATA_PATH = "ml-100k.data"

# %%
# filepath = maybe_download(DATA_URL, DATA_PATH)

# %%
# COL_USER = "UserId"
# COL_ITEM = "MovieId"
# COL_RATING = "Rating"
# COL_PREDICTION = "Rating"
# COL_TIMESTAMP = "Timestamp"

# %%
# data = pd.read_csv(filepath,sep = "\t", names = [COL_USER, COL_ITEM, COL_RATING, COL_TIMESTAMP])

# %%
# data.head()

# %%
# data.describe()

# %%
# print("Total number of RATINGS : \t{}\n".format(data.shape[0]),
#       "Total number of USERS : \t{}\n".format(data[COL_USER].nunique()),
#       "Total number of ITEMS : \t{}\n".format(data[COL_ITEM].nunique()))
# # data['userId'].nunique() counts the distinct number of users represented in your dataset based on their unique userId values.

# %%
# data[COL_TIMESTAMP]= data.apply(
#     lambda x: datetime.strftime(datetime(1970, 1, 1, 0, 0, 0) + timedelta(seconds=x[COL_TIMESTAMP].item()), "%Y-%m-%d %H:%M:%S"),
#     axis=1
# )

# %%
# data.head()

# %%
# data_train, data_test = python_random_split(data, ratio = 0.7)

# %%
# print(data_train.shape[0], data_test.shape[0])

# %%
# data_train.head()

# %%
# data_test.head()

# %%
# data_train, data_validate, data_test = python_random_split(data, ratio=[0.6, 0.2, 0.2])
# data_train.shape[0], data_validate.shape[0], data_test.shape[0]

# %% [markdown]
# The logging module is a built-in Python library designed to provide a flexible and powerful framework for recording events, messages, and errors that occur within your programs. It helps you track what's happening inside your code, making it easier to diagnose problems, monitor performance, and gather information for analysis.
# DEBUG: Detailed information for debugging.
# INFO: General informational messages.
# WARNING: Something unexpected happened or could happen.
# ERROR: Something has failed.
# CRITICAL: A serious error; the program might not be able to continue.

# %%
import logging
import numpy as np
import pandas as pd
from sklearn.preprocessing import minmax_scale

# %% [markdown]
# The sklearn.preprocessing module in scikit-learn is a collection of tools designed to transform raw feature data into a format that is more suitable for machine learning algorithms.
# minmax_scale Scales features to a specified range, usually between 0 and 1. This is known as min-max scaling or normalization.
#
#
# x_scaled = (x - min(x)) / (max(x) - min(x))
# where: - x_scaled is the scaled value - x is the original value - min(x) and max(x) are the minimum and maximum values of the feature, respectively

# %%
from recommenders.utils.timer import Timer
from recommenders.datasets import movielens
from recommenders.utils.python_utils import binarize
from recommenders.datasets.python_splitters import python_stratified_split
from recommenders.models.sar import SAR

# %%
from recommenders.evaluation.python_evaluation import (
    map_at_k,
    ndcg_at_k,
    precision_at_k,
    recall_at_k,
    rmse,
    mae,
    logloss,
    rsquared,
    exp_var
)

# %%
# Data Loading Params
TOP_K = 10
MOVIELENS_DATA_SIZE = "1M"
USER_COL = "userID"
ITEM_COL = "itemID"
RATING_COL = "rating"
TIMESTAMP_COL = "timestamp"
PREDICTION_COL = "prediction"

# Train test split ratio
SPLIT_RATIO = 0.75

# Model settings
SIMILARITY_TYPE = "jaccard"
TIME_DECAY = 30 # number of days until the weight of the ratings are decayed by 1/2

SEED = 42

# %%
logging.basicConfig(level=logging.DEBUG, format="%(levelname)-8s %(message)s")

# %%
# Data Loading
data = movielens.load_pandas_df(
    size=MOVIELENS_DATA_SIZE
)
# Out:
# 100%|██████████| 5.78k/5.78k [00:00<00:00, 6.18kKB/s]

# %%
# Convert the float precision to 32-bit in order to reduce memory consumption
data[RATING_COL] = data[RATING_COL].astype(np.float32)

# %%
data.head()
# Out:
#    userID  itemID  rating  timestamp
# 0       1    1193     5.0  978300760
# 1       1     661     3.0  978302109
# 2       1     914     3.0  978301968
# 3       1    3408     4.0  978300275
# 4       1    2355     5.0  978824291

# %%
# Data Splititng
train, test = python_stratified_split(data, ratio = SPLIT_RATIO, filter_by="user", col_user = USER_COL, col_item = ITEM_COL, seed = SEED)

# %% [markdown]
# Stratified splitting is a way to divide your dataset into training and testing sets while ensuring that the distribution of a specific feature (in this case, the "user") is roughly preserved in both sets.
# This is crucial for recommender systems because different users have varying levels of activity (e.g., some rate many movies, others rate few). A stratified split helps make sure your model is trained and evaluated on a representative sample of user behaviors.
# y: The splitting process involves randomness to assign users to either the training or testing set. The seed parameter controls this randomness. By setting a specific seed value (e.g., SEED=42), you ensure that the random number generator used during splitting produces the same sequence of random numbers every time the function is run.
#
#
#
#
# SAR generates recommendations based on user preferences, all users that are in the test set must also exist in the training set. For this case, we can use the provided python_stratified_split function which holds out a percentage (in this case 25%) of items from each user, but ensures all users are in both

# %%
print("""
Train:
Total Ratings: {train_total}
Unique Users: {train_users}
Unique Items: {train_items}

Test:
Total Ratings: {test_total}
Unique Users: {test_users}
Unique Items: {test_items}
""".format(
    train_total=len(train),
    train_users=len(train[USER_COL].unique()),
    train_items=len(train[ITEM_COL].unique()),
    test_total=len(test),
    test_users=len(test[USER_COL].unique()),
    test_items=len(test[ITEM_COL].unique()),
))
# Out:
# Train:
# Total Ratings: 750121
# Unique Users: 6040
# Unique Items: 3669
#
# Test:
# Total Ratings: 250088
# Unique Users: 6040
# Unique Items: 3509

# %%
# SAR Model
# 1. Instantiation
model = SAR(
    col_user = USER_COL,
    col_item=ITEM_COL,
    col_rating=RATING_COL,
    col_timestamp=TIMESTAMP_COL,
    similarity_type=SIMILARITY_TYPE,
    time_decay_coefficient=30,
    timedecay_formula=True,

)

# %% [markdown]
# # 2. Training
# SAR first computes an item-to-item co-occurence matrix. Co-occurence represents the number of times two items appear together for any given user. Once we have the co-occurence matrix, we compute an item similarity matrix by rescaling the cooccurences by a given metric (Jaccard similarity in this example).
#
#
# We also compute an affinity matrix to capture the strength of the relationship between each user and each item. Affinity is driven by different types (like rating or viewing a movie), and by the time of the event.
#
# Recommendations are achieved by multiplying the affinity matrix
#  and the similarity matrix
# . The result is a recommendation score matrix
# . We compute the top-k results for each user in the recommend_k_items

# %%
# 2. Model Training
with Timer() as train_time:
    model.fit(train)
print(f"Took {train_time.interval} seconds for training.")
# Out:
# Took 6.347303831999852 seconds for training.

# %%
# 3. Model Testing
with Timer() as test_time:
    top_k = model.recommend_k_items(test, top_k=TOP_K, remove_seen=True)
print("Took {} seconds for prediction.".format(test_time.interval))
# Out:
# Took 3.386957013999563 seconds for prediction.

# %%
top_k.head()
# Out:
#    userID  itemID    prediction
# 0       1    1196  3.710560e-07
# 1       1     588  3.693333e-07
# 2       1     318  3.675084e-07
# 3       1    1265  3.653713e-07
# 4       1    2716  3.634300e-07

# %%
# 4. Model Evaluation
# Ranking metrics
eval_map = map_at_k(test, top_k, col_user=USER_COL, col_item=ITEM_COL, col_rating=RATING_COL, k=TOP_K)
eval_ndcg = ndcg_at_k(test, top_k, col_user=USER_COL, col_item=ITEM_COL, col_rating=RATING_COL, k=TOP_K)
eval_precision = precision_at_k(test, top_k, col_user=USER_COL, col_item=ITEM_COL, col_rating=RATING_COL, k=TOP_K)
eval_recall = recall_at_k(test, top_k, col_user=USER_COL, col_item=ITEM_COL, col_rating=RATING_COL, k=TOP_K)

# %%
# Rating metrics
eval_rmse = rmse(test, top_k, col_user=USER_COL, col_item=ITEM_COL, col_rating=RATING_COL)
eval_mae = mae(test, top_k, col_user=USER_COL, col_item=ITEM_COL, col_rating=RATING_COL)
eval_rsquared = rsquared(test, top_k, col_user=USER_COL, col_item=ITEM_COL, col_rating=RATING_COL)
eval_exp_var = exp_var(test, top_k, col_user=USER_COL, col_item=ITEM_COL, col_rating=RATING_COL)

# %%
positivity_threshold = 2
test_bin = test.copy()
test_bin[RATING_COL] = binarize(test_bin[RATING_COL], positivity_threshold)

top_k_prob = top_k.copy()
top_k_prob[PREDICTION_COL] = minmax_scale(top_k_prob[PREDICTION_COL].astype(float))

eval_logloss = logloss(
    test_bin, top_k_prob, col_user=USER_COL, col_item=ITEM_COL, col_rating=RATING_COL
)

# %%
print("Model:\t\tSAR",
      "Top K:\t\t%d" % TOP_K,
      "MAP:\t\t%f" % eval_map,
      "NDCG:\t\t%f" % eval_ndcg,
      "Precision@K:\t%f" % eval_precision,
      "Recall@K:\t%f" % eval_recall,
      "RMSE:\t\t%f" % eval_rmse,
      "MAE:\t\t%f" % eval_mae,
      "R2:\t\t%f" % eval_rsquared,
      "Exp var:\t%f" % eval_exp_var,
      "Logloss:\t%f" % eval_logloss,
      sep='\n')
# Out:
# Model:		SAR
# Top K:		10
# MAP:		0.185099
# NDCG:		0.309862
# Precision@K:	0.279222
# Recall@K:	0.109562
# RMSE:		4.376662
# MAE:		4.015169
# R2:		-19.559593
# Exp var:	-3.758149
# Logloss:	17.742497

# %%
# The results for user_id 280
user_id = 280

user_input = pd.DataFrame(dict(userID=[user_id]))

# %%
# Out:
#        userID
# count     1.0
# mean    280.0
# std       NaN
# min     280.0
# 25%     280.0
# 50%     280.0
# 75%     280.0
# max     280.0

# %%
ground_truth = test[test[USER_COL] == user_id]
ground_truth
prediction = model.recommend_k_items(user_input, remove_seen=True)
df = pd.merge(ground_truth, prediction, on=[USER_COL, ITEM_COL], how="left").dropna().sort_values(by=PREDICTION_COL, ascending=False)
df
# Out:
#    userID  itemID  rating  timestamp    prediction
# 0     280    1294     4.0  976574915  1.801792e-07
# 1     280    1307     4.0  976575188  1.719844e-07
